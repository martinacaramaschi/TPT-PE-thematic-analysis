# %% [markdown]
# <a href="https://colab.research.google.com/github/martinacaramaschi/TPT-PE-thematic-analysis/blob/main/Nationality_analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysing nationality of institutions publishing on Physics Education journal

# %% [markdown]
# I am using OpenAlex dataset to extract data for different years:
# - 2019
# - 2010
# - 2000
# - 1980
# - 1966
#
# Based on the information gained from the web site on the 24th of August, 2025, we group the insitutions for county and for continent. Then, we sum how many articles per contry and per continent are published each year.

# %% [markdown]
# Year: 2019
#
# query: https://openalex.org/works?page=1&filter=primary_location.source.id:s43510877,publication_year:2019

# %%
# List of institutions with the number of articles

institutions_with_counts = [
    ("University of North Carolina at Asheville", 5),
    ("The University of Sydney", 4),
    ("Lund University", 4),
    ("Kristianstad University", 4),
    ("University of Szeged", 4),
    ("Eötvös Loránd University", 3),
    ("Centre National de la Recherche Scientifique", 3),
    ("University of Oslo", 3),
    ("Alberto Hurtado University", 3),
    ("University of San Carlos", 3),
    ("Uppsala University", 2),
    ("University of Ljubljana", 2),
    ("University of Graz", 2),
    ("The University of Western Australia", 2),
    ("Universidad de la República de Uruguay", 2),
    ("Australian Government", 2),
    ("CNRS Ingénierie", 2),
    ("Ministerio de Educación y Cultura", 2),
    ("Srinakharinwirot University", 2),
    ("St. Lawrence University", 1),
    ("Université Paris-Sud", 1),
    ("Rutgers, The State University of New Jersey", 1),
    ("Karlsruhe Institute of Technology", 1),
    ("Universidad de Santiago de Chile", 1),
    ("Karnatak University", 1),
    ("Seattle Pacific University", 1),
    ("Hiroshima University", 1),
    ("Leuphana University of Lüneburg", 1),
    ("University of Technology Sydney", 1),
    ("Balıkesir University", 1),
    ("Australian National University", 1),
    ("Michigan Technological University", 1),
    ("Sebelas Maret University", 1),
    ("Universidade Federal de Mato Grosso do Sul", 1),
    ("University of Copenhagen", 1),
    ("Jagiellonian University", 1),
    ("Yogyakarta State University", 1),
    ("Universidade Tecnológica Federal do Paraná", 1),
    ("Burapha University", 1),
    ("Helmholtz Association of German Research Centres", 1),
    ("University of Salerno", 1),
    ("National Measurement Institute", 1),
    ("Université Toulouse III - Paul Sabatier", 1),
    ("University of Padua", 1),
    ("University of British Columbia", 1),
    ("University of Nottingham", 1),
    ("University of Shanghai for Science and Technology", 1),
    ("State University of Semarang", 1),
    ("Giresun University", 1),
    ("University of Nis", 1),
    ("Stockholm University", 1),
    ("Thapar Institute of Engineering & Technology", 1),
    ("University of Sannio", 1),
    ("The University of Queensland", 1),
    ("National Technical University of Athens", 1),
    ("University of Eastern Finland", 1),
    ("Khalifa University of Science and Technology", 1),
    ("Western Norway University of Applied Sciences", 1),
    ("Universidade do Porto", 1),
    ("University of Winchester", 1),
    ("Laboratoire d'Analyse et d'Architecture des Systèmes", 1),
    ("University of Hull", 1),
    ("Plovdiv University", 1),
    ("Dokuz Eylül University", 1),
    ("University of Ioannina", 1),
    ("Institut National des Sciences Appliquées de Toulouse", 1),
    ("Millennium Institute", 1),
    ("Europa-Universität Flensburg", 1),
    ("University of Washington", 1),
    ("Czech Academy of Sciences", 1),
    ("Instituto Politécnico de Lisboa", 1),
    ("Université Paris Cité", 1),
    ("Norwegian University of Science and Technology", 1),
    ("University of Pavol Jozef Šafárik", 1),
    ("Institut National Polytechnique de Toulouse", 1),
    ("Charles University", 1),
    ("Aristotle University of Thessaloniki", 1),
    ("Masaryk University", 1),
    ("University of Cambridge", 1),
    ("Universitas Ahmad Dahlan", 1),
    ("Sriwijaya University", 1),
    ("Université Paris-Saclay", 1),
    ("Queensland Museum", 1),
    ("Laboratoire de physique des Solides", 1),
    ("Government Medical College, Amritsar", 1),
    ("Millennium Science Initiative", 1),
    ("University of Surrey", 1),
    ("Instituto Federal Goiano", 1),
    ("Beit Berl College", 1),
    ("Cebu Technological University", 1),
    ("Rottenburg University of Applied Forest Sciences", 1),
    ("University of Hawaii at Hilo", 1),
    ("University at Albany, State University of New York", 1),
    ("Humboldt-Universität zu Berlin", 1),
    ("University of Oxford", 1),
    ("Universidad de Sonora", 1),
    ("Quantum (Australia)", 1),
    ("Institut d’Optique Graduate School", 1),
    ("Mi̇lli̇ Eği̇ti̇m Bakanliği", 1),
    ("CMR University", 1),
    ("Sunan Gunung Djati State Islamic University Bandung", 1),
    ("University of International Business", 1),
    ("Escuela Colombiana de Ingenieria Julio Garavito", 1),
    ("Lone Star College–Tomball", 1),
    ("National Institute of Optics", 1),
    ("Regional Centre of Advanced Technologies and Materials", 1),
    ("Suleyman Demirel University", 1),
    ("Czech Academy of Sciences, Institute of Physics", 1),
    ("Teem Photonics (France)", 1),
    ("Glazov State Pedagogical Institute Named after VG Korolenko", 1),
    ("ARC Centre of Excellence for Gravitational Wave Discovery", 1),
    ("Laboratoire Matière et Systèmes Complexes", 1),
    ("University of Washington Bothell", 1),
    ("University Colleges Leuven-Limburg", 1),
    ("Services Australia", 1),
    ("Instituto di Biofisica", 1),
    ("Brandenburg University of Applied Sciences", 1),
    ("Institute for Complex Systems", 1),
    ("National Research Council", 1),
    ("Technical College of Applied Sciences", 1),
    ("Institut des Sciences de l'Information et de leurs Interactions", 1),
    ("Department of Social Services", 1),
    ("University of Southampton", 1),
    ("Department of Industry, Science and Resources", 1),
    ("Université de Toulouse", 1),
    ("University of Florence", 1),
    ("Kırıkkale University", 1),
    ("University of Manitoba", 1),
    ("Universidade Federal do Paraná", 1),
    ("Nazarbayev University", 1),
    ("California State University, Fresno", 1),
    ("Palacký University Olomouc", 1),
    ("University of Coimbra", 1),
    ("N. I. Lobachevsky State University of Nizhny Novgorod", 1),
    ("University of Worcester", 1),
    ("Mälardalen University", 1),
    ("Lone Star College", 1),
    ("University of Oklahoma", 1),
    ("Graduate School USA", 1),
    ("Nanjing University", 1),
    ("University of South Carolina Beaufort", 1),
    ("Okan University", 1),
    ("Delft University of Technology", 1),
    ("Indian Institute of Engineering Science and Technology, Shibpur", 1),
    ("University of Edinburgh", 1),
    ("KU Leuven", 1)
]

# Mapping Country → Institution list
mapping_country = {
    "Australia": ["The University of Sydney", "The University of Western Australia", "Australian Government", "University of Queensland", "Australian National University", "Quantum (Australia)", "ARC Centre of Excellence for Gravitational Wave Discovery", "Services Australia", "Department of Industry, Science and Resources"],
    "USA": ["University of North Carolina at Asheville", "Rutgers, The State University of New Jersey", "Seattle Pacific University", "Michigan Technological University", "St. Lawrence University", "University of Washington", "University of Hawaii at Hilo", "University at Albany, State University of New York", "University of Oklahoma", "Lone Star College–Tomball", "University of South Carolina Beaufort", "California State University, Fresno", "Graduate School USA"],
    "UK": ["University of Nottingham", "University of Cambridge", "University of Oxford", "University of Southampton", "University of Surrey", "University of Winchester", "University of Hull", "University of Worcester", "University of Edinburgh"],
    "France": ["Centre National de la Recherche Scientifique", "Université Paris-Sud", "Université Toulouse III - Paul Sabatier", "Université Paris Cité", "Université Paris-Saclay", "Institut d’Optique Graduate School", "Teem Photonics (France)"],
    "Italy": ["University of Salerno", "University of Padua", "University of Sannio", "University of Florence", "Instituto di Biofisica", "National Institute of Optics", "Institute for Complex Systems", "National Research Council"],
    "Germany": ["Karlsruhe Institute of Technology", "Leuphana University of Lüneburg", "Helmholtz Association of German Research Centres", "Europa-Universität Flensburg", "Humboldt-Universität zu Berlin", "Brandenburg University of Applied Sciences", "Rottenburg University of Applied Forest Sciences"],
    "Spain": [],
    "Brazil": ["Universidade Federal de Mato Grosso do Sul", "Universidade Tecnológica Federal do Paraná", "Instituto Federal Goiano", "Universidade Federal do Paraná"],
    "Norway": ["University of Oslo", "Western Norway University of Applied Sciences", "Norwegian University of Science and Technology"],
    "Sweden": ["Lund University", "Kristianstad University", "Uppsala University", "Stockholm University", "Mälardalen University"],
    "Hungary": ["University of Szeged", "Eötvös Loránd University"],
    "Chile": ["Universidad de Santiago de Chile"],
    "India": ["Karnatak University", "Government Medical College, Amritsar", "CMR University", "Indian Institute of Engineering Science and Technology, Shibpur"],
    "Japan": ["Hiroshima University"],
    "China": ["Nanjing University", "University of Shanghai for Science and Technology"],
    "Netherlands": ["Delft University of Technology"],
    "Portugal": ["Instituto Politécnico de Lisboa", "Universidade do Porto", "University of Coimbra"],
    "Czech Republic": ["Czech Academy of Sciences", "Charles University", "Masaryk University", "Palacký University Olomouc"],
    "Greece": ["Aristotle University of Thessaloniki", "National Technical University of Athens", "University of Ioannina"],
    "Finland": ["University of Eastern Finland"],
    "Poland": ["Jagiellonian University"],
    "Slovenia": ["University of Ljubljana"],
    "Austria": ["University of Graz"],
    "Turkey": ["Balıkesir University", "Dokuz Eylül University", "Giresun University", "Kırıkkale University", "Okan University"],
    "Kazakhstan": ["Nazarbayev University"],
    "Canada": ["University of British Columbia", "University of Manitoba"]
}

# Mapping Continent → Country
mapping_continent = {
    "Europe": ["UK", "France", "Italy", "Germany", "Spain", "Norway", "Sweden", "Hungary", "Netherlands", "Portugal", "Czech Republic", "Greece", "Finland", "Poland", "Slovenia", "Austria", "Turkey"],
    "North America": ["USA", "Canada"],
    "South America": ["Brazil", "Chile"],
    "Asia": ["India", "Japan", "China", "Kazakhstan"],
    "Oceania": ["Australia"]
}

# Grouping by Country
country_counts = {}
for inst, count in institutions_with_counts:
    for country, inst_list in mapping_country.items():
        if inst in inst_list:
            country_counts[country] = country_counts.get(country, 0) + count
            break

# Grouping by Continent
continent_counts = {}
for continent, countries in mapping_continent.items():
    continent_counts[continent] = sum(country_counts.get(c, 0) for c in countries)

# Final output
print("Articles by contry:")
for country, total in sorted(country_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{country}: {total}")

print("\nArticols by continent:")
for continent, total in sorted(continent_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{continent}: {total}")

print(f"\nTotal articles showing institution: {sum(country_counts.values())}")

print(f"\nOver total articles found: {215}")
# Out:
# Articles by contry:
# USA: 17
# Australia: 13
# Sweden: 12
# France: 9
# UK: 9
# Italy: 8
# Hungary: 7
# Germany: 7
# Norway: 5
# Turkey: 5
# India: 4
# Brazil: 4
# Czech Republic: 4
# Greece: 3
# Portugal: 3
# Slovenia: 2
# Austria: 2
# Canada: 2
# China: 2
# Chile: 1
# Japan: 1
# Poland: 1
# Finland: 1
# Kazakhstan: 1
# Netherlands: 1
#
# Articols by continent:
# Europe: 79
# North America: 19
# Oceania: 13
# Asia: 8
# South America: 5
#
# Total articles showing institution: 124
#
# Over total articles found: 215

# %% [markdown]
# Year: 2010
#
# query: penalex.org/works?page=1&filter=primary_location.source.id:s43510877,publication_year:2010

# %%
import pandas as pd

# Data dictionary
data = {
    "Queensland University of Technology": 3,
    "Israel Academy of Sciences and Humanities": 3,
    "Northeastern University": 2,
    "University of Ljubljana": 2,
    "University of Cambridge": 2,
    "Swedish Society for Nature Conservation": 2,
    "Benemérita Universidad Autónoma de Puebla": 2,
    "Mills College": 2,
    "Universidade da Coruña": 1,
    "Tata Institute of Fundamental Research": 1,
    "West Virginia University": 1,
    "Universidad Complutense de Madrid": 1,
    "Ben-Gurion University of the Negev": 1,
    "Pontificia Universidad Católica de Valparaíso": 1,
    "University of Padua": 1,
    "Universiti Sains Malaysia": 1,
    "Bar-Ilan University": 1,
    "University of British Columbia": 1,
    "Eastern Illinois University": 1,
    "University of Trás-os-Montes and Alto Douro": 1,
    "Henry Ford College": 1,
    "Avinashilingam University": 1,
    "University of Arkansas at Monticello": 1,
    "Nanyang Technological University": 1,
    "Technological Educational Institute of Central Greece": 1,
    "Dokuz Eylül University": 1,
    "National Institute of Education": 1,
    "Europa-Universität Flensburg": 1,
    "Charles University": 1,
    "Aristotle University of Thessaloniki": 1,
    "Cumbria Northumberland Tyne and Wear NHS Foundation Trust": 1,
    "University of Pavia": 1,
    "Mahidol University": 1,
    "Government of India": 1,
    "Azrieli College of Engineering Jerusalem": 1,
    "University of Manchester": 1,
    "Leibniz Institute for Solid State and Materials Research": 1,
    "Department of Atomic Energy": 1,
    "Leibniz Association": 1,
    "Ludwigsburg University of Education": 1,
    "Universidad de Sonora": 1,
    "Andover Eye Associates": 1,
    "Kryvyi Rih State Pedagogical University": 1,
    "St George's Park": 1,
    "Market Harborough Hospital": 1,
    "University of Bergen": 1,
    "Nottingham Trent University": 1,
    "Weizmann Institute of Science": 1,
    "University of Bari Aldo Moro": 1,
    "Homi Bhabha Centre for Science Education": 1,
    "University of Winnipeg": 1,
    "Marshall University": 1,
    "Universidad Nacional Autónoma de México": 1,
    "University of Sheffield": 1
}

# Institution → Country
institution_to_country = {
    "Queensland University of Technology": "Australia",
    "Israel Academy of Sciences and Humanities": "Israel",
    "Northeastern University": "USA",
    "University of Ljubljana": "Slovenia",
    "University of Cambridge": "UK",
    "Swedish Society for Nature Conservation": "Sweden",
    "Benemérita Universidad Autónoma de Puebla": "Mexico",
    "Mills College": "USA",
    "Universidade da Coruña": "Spain",
    "Tata Institute of Fundamental Research": "India",
    "West Virginia University": "USA",
    "Universidad Complutense de Madrid": "Spain",
    "Ben-Gurion University of the Negev": "Israel",
    "Pontificia Universidad Católica de Valparaíso": "Chile",
    "University of Padua": "Italy",
    "Universiti Sains Malaysia": "Malaysia",
    "Bar-Ilan University": "Israel",
    "University of British Columbia": "Canada",
    "Eastern Illinois University": "USA",
    "University of Trás-os-Montes and Alto Douro": "Portugal",
    "Henry Ford College": "USA",
    "Avinashilingam University": "India",
    "University of Arkansas at Monticello": "USA",
    "Nanyang Technological University": "Singapore",
    "Technological Educational Institute of Central Greece": "Greece",
    "Dokuz Eylül University": "Turkey",
    "National Institute of Education": "Singapore",
    "Europa-Universität Flensburg": "Germany",
    "Charles University": "Czech Republic",
    "Aristotle University of Thessaloniki": "Greece",
    "Cumbria Northumberland Tyne and Wear NHS Foundation Trust": "UK",
    "University of Pavia": "Italy",
    "Mahidol University": "Thailand",
    "Government of India": "India",
    "Azrieli College of Engineering Jerusalem": "Israel",
    "University of Manchester": "UK",
    "Leibniz Institute for Solid State and Materials Research": "Germany",
    "Department of Atomic Energy": "India",
    "Leibniz Association": "Germany",
    "Ludwigsburg University of Education": "Germany",
    "Universidad de Sonora": "Mexico",
    "Andover Eye Associates": "USA",
    "Kryvyi Rih State Pedagogical University": "Ukraine",
    "St George's Park": "UK",
    "Market Harborough Hospital": "UK",
    "University of Bergen": "Norway",
    "Nottingham Trent University": "UK",
    "Weizmann Institute of Science": "Israel",
    "University of Bari Aldo Moro": "Italy",
    "Homi Bhabha Centre for Science Education": "India",
    "University of Winnipeg": "Canada",
    "Marshall University": "USA",
    "Universidad Nacional Autónoma de México": "Mexico",
    "University of Sheffield": "UK"
}

# Country → Continent
country_to_continent = {
    "Australia": "Oceania",
    "Israel": "Asia",
    "USA": "North America",
    "Slovenia": "Europe",
    "UK": "Europe",
    "Sweden": "Europe",
    "Mexico": "North America",
    "Spain": "Europe",
    "India": "Asia",
    "Chile": "South America",
    "Italy": "Europe",
    "Malaysia": "Asia",
    "Canada": "North America",
    "Portugal": "Europe",
    "Singapore": "Asia",
    "Greece": "Europe",
    "Turkey": "Asia",
    "Germany": "Europe",
    "Czech Republic": "Europe",
    "Thailand": "Asia",
    "Ukraine": "Europe",
    "Norway": "Europe"
}

# Create DataFrame
df = pd.DataFrame(list(data.items()), columns=["Institution", "Publications"])
df["Country"] = df["Institution"].map(institution_to_country)
df["Continent"] = df["Country"].map(country_to_continent)

# Group by Country
country_counts = df.groupby("Country")["Publications"].sum().sort_values(ascending=False)
# Group by Continent
continent_counts = df.groupby("Continent")["Publications"].sum().sort_values(ascending=False)

# Final output
print("Articles by contry:")
for country, total in sorted(country_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{country}: {total}")

print("\nArticols by continent:")
for continent, total in sorted(continent_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{continent}: {total}")

print(f"\nTotal articles showing institution: {country_counts.sum()}")
print(f"Over total articles found: {131}")
# Out:
# Articles by contry:
# USA: 10
# UK: 8
# Israel: 7
# India: 5
# Germany: 4
# Mexico: 4
# Australia: 3
# Italy: 3
# Greece: 2
# Canada: 2
# Sweden: 2
# Spain: 2
# Singapore: 2
# Slovenia: 2
# Chile: 1
# Czech Republic: 1
# Malaysia: 1
# Norway: 1
# Portugal: 1
# Thailand: 1
# Turkey: 1
# Ukraine: 1
#
# Articols by continent:
# Europe: 27
# Asia: 17
# North America: 16
# Oceania: 3
# South America: 1
#
# Total articles showing institution: 64
# Over total articles found: 131

# %% [markdown]
# Year: 2000
#
# Query: https://openalex.org/works?page=1&filter=primary_location.source.id:s43510877,publication_year:2000

# %%
# List of institutions with number of articles
institutions_with_counts = [
    ("Loughborough University", 4),
    ("Chinese University of Hong Kong", 3),
    ("Universities UK", 3),
    ("University of Cambridge", 3),
    ("Canterbury Christ Church University", 2),
    ("ING Direct", 2),
    ("Stockholm University", 2),
    ("York University", 2),
    ("Hebrew University of Jerusalem", 2),
    ("The Open University", 2),
    ("Edwards (United Kingdom)", 2),
    ("University of Haifa", 2),
    ("Oranim Academic College of Education", 1),
    ("Goethe University Frankfurt", 1),
    ("Institute of Physics", 1),
    ("Monash University Malaysia", 1),
    ("University of Udine", 1),
    ("American Physical Society", 1),
    ("University of Vienna", 1),
    ("University of Leeds", 1),
    ("Corning (United States)", 1),
    ("Unilever (United Kingdom)", 1),
    ("East Sussex County Council", 1),
    ("Gustavus Adolphus College", 1),
    ("University of Bradford", 1),
    ("University of Botswana", 1),
    ("Universitat de València", 1),
    ("Universidade Federal Fluminense", 1),
    ("Nanyang Technological University", 1),
    ("Southern Methodist University", 1),
    ("Plovdiv University", 1),
    ("Capilano University", 1),
    ("National and Kapodistrian University of Athens", 1),
    ("Princeton University", 1),
    ("University of Washington", 1),
    ("Czech Academy of Sciences", 1),
    ("Masaryk University", 1),
    ("University of Massachusetts Amherst", 1),
    ("Manchester Grammar School", 1),
    ("Education Scotland", 1),
    ("Varberg Hospital", 1),
    ("Wiltshire College", 1),
    ("Scottish Government", 1),
    ("City and Islington College", 1),
    ("Heriot-Watt University", 1),
    ("University of Cyprus", 1),
    ("The Edgbaston Hospital", 1),
    ("Homerton University Hospital", 1),
    ("BMI Healthcare", 1),
    ("Diplomatic Academy of Vienna", 1),
    ("Homerton University Hospital NHS Foundation Trust", 1),
    ("Czech Academy of Sciences, Institute of Physics", 1),
    ("Digital Catapult", 1),
    ("Cambridge University Press", 1),
    ("Grammar School", 1),
    ("Mahanakorn University of Technology", 1),
    ("University of York", 1),
    ("Laurentian University", 1),
    ("University of Neuchâtel", 1),
    ("Sofia University \"St. Kliment Ohridski\"", 1),
    ("University of Wisconsin–Oshkosh", 1),
    ("European Organization for Nuclear Research", 1),
    ("Polytechnic University of Bari", 1),
    ("New York City College of Technology", 1),
    ("Universidad de Extremadura", 1),
    ("The University of Texas at Austin", 1),
    ("V. N. Karazin Kharkiv National University", 1),
    ("University of Roehampton", 1),
    ("University of Sheffield", 1),
    ("Banaras Hindu University", 1),
    ("Stanford University", 1)
]

# Example: mapping institutions to countries
mapping_country = {
    "Loughborough University": "UK",
    "Chinese University of Hong Kong": "China",
    "Universities UK": "UK",
    "University of Cambridge": "UK",
    "Canterbury Christ Church University": "UK",
    "ING Direct": "USA",
    "Stockholm University": "Sweden",
    "York University": "Canada",
    "Hebrew University of Jerusalem": "Israel",
    "The Open University": "UK",
    "Edwards (United Kingdom)": "UK",
    "University of Haifa": "Israel",
    "Oranim Academic College of Education": "Israel",
    "Goethe University Frankfurt": "Germany",
    "Institute of Physics": "UK",
    "Monash University Malaysia": "Malaysia",
    "University of Udine": "Italy",
    "American Physical Society": "USA",
    "University of Vienna": "Austria",
    "University of Leeds": "UK",
    "Corning (United States)": "USA",
    "Unilever (United Kingdom)": "UK",
    "East Sussex County Council": "UK",
    "Gustavus Adolphus College": "USA",
    "University of Bradford": "UK",
    "University of Botswana": "Botswana",
    "Universitat de València": "Spain",
    "Universidade Federal Fluminense": "Brazil",
    "Nanyang Technological University": "Singapore",
    "Southern Methodist University": "USA",
    "Plovdiv University": "Bulgaria",
    "Capilano University": "Canada",
    "National and Kapodistrian University of Athens": "Greece",
    "Princeton University": "USA",
    "University of Washington": "USA",
    "Czech Academy of Sciences": "Czech Republic",
    "Masaryk University": "Czech Republic",
    "University of Massachusetts Amherst": "USA",
    "Manchester Grammar School": "UK",
    "Education Scotland": "UK",
    "Varberg Hospital": "Sweden",
    "Wiltshire College": "UK",
    "Scottish Government": "UK",
    "City and Islington College": "UK",
    "Heriot-Watt University": "UK",
    "University of Cyprus": "Cyprus",
    "The Edgbaston Hospital": "UK",
    "Homerton University Hospital": "UK",
    "BMI Healthcare": "UK",
    "Diplomatic Academy of Vienna": "Austria",
    "Homerton University Hospital NHS Foundation Trust": "UK",
    "Czech Academy of Sciences, Institute of Physics": "Czech Republic",
    "Digital Catapult": "UK",
    "Cambridge University Press": "UK",
    "Grammar School": "UK",
    "Mahanakorn University of Technology": "Thailand",
    "University of York": "UK",
    "Laurentian University": "Canada",
    "University of Neuchâtel": "Switzerland",
    "Sofia University \"St. Kliment Ohridski\"": "Bulgaria",
    "University of Wisconsin–Oshkosh": "USA",
    "European Organization for Nuclear Research": "Switzerland",
    "Polytechnic University of Bari": "Italy",
    "New York City College of Technology": "USA",
    "Universidad de Extremadura": "Spain",
    "The University of Texas at Austin": "USA",
    "V. N. Karazin Kharkiv National University": "Ukraine",
    "University of Roehampton": "UK",
    "University of Sheffield": "UK",
    "Banaras Hindu University": "India",
    "Stanford University": "USA"
}

# Mapping country -> continent
mapping_continent = {
    "Europe": ["UK", "Germany", "Sweden", "Italy", "Austria", "Spain", "Czech Republic", "Greece", "Bulgaria", "Cyprus", "Switzerland", "Ukraine"],
    "North America": ["USA", "Canada"],
    "South America": ["Brazil"],
    "Asia": ["Israel", "Malaysia", "Singapore", "India", "Thailand", "China"],
    "Oceania": ["Australia"],
    "Africa": ["Botswana"]
}

# Grouping by country
country_counts = {}
for inst, count in institutions_with_counts:
    country = mapping_country.get(inst)
    if country:
        country_counts[country] = country_counts.get(country, 0) + count

# Grouping by continent
continent_counts = {}
for continent, countries in mapping_continent.items():
    continent_counts[continent] = sum(country_counts.get(c, 0) for c in countries)

# Output
print("Articles by country:")
for country, total in sorted(country_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{country}: {total}")

print("\nArticles by continent:")
for continent, total in sorted(continent_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{continent}: {total}")

print(f"\nTotal articles showing institution: {sum(country_counts.values())}")
print(f"Over total articles found: {192}")
# Out:
# Articles by country:
# UK: 37
# USA: 13
# Israel: 5
# Canada: 4
# China: 3
# Sweden: 3
# Czech Republic: 3
# Italy: 2
# Austria: 2
# Spain: 2
# Bulgaria: 2
# Switzerland: 2
# Germany: 1
# Malaysia: 1
# Botswana: 1
# Brazil: 1
# Singapore: 1
# Greece: 1
# Cyprus: 1
# Thailand: 1
# Ukraine: 1
# India: 1
#
# Articles by continent:
# Europe: 57
# North America: 17
# Asia: 12
# South America: 1
# Africa: 1
# Oceania: 0
#
# Total articles showing institution: 88
# Over total articles found: 192

# %% [markdown]
# Year: 1980
#
# Query: https://openalex.org/works?page=1&filter=primary_location.source.id:s43510877,publication_year:1980

# %%
# New list of institutions with number of articles
institutions_with_counts = [
    ("University of London", 3),
    ("Robert Gordon's College", 3),
    ("University of Manchester", 2),
    ("Australian National University", 1),
    ("Royal Military Academy Sandhurst", 1),
    ("University of Nairobi", 1),
    ("Rutherford Appleton Laboratory", 1),
    ("IBM (United States)", 1),
    ("University of Chester", 1),
    ("University of Nottingham", 1),
    ("University of Waterloo", 1),
    ("Science and Technology Facilities Council", 1),
    ("Indian Institute of Technology Bombay", 1),
    ("Queen Mary University of London", 1),
    ("Chinese University of Hong Kong", 1),
    ("City, University of London", 1),
    ("University of Kent", 1),
    ("University of Cambridge", 1),
    ("Indian Institute of Technology Madras", 1),
    ("University College Cork", 1),
    ("Macclesfield College", 1),
    ("University of Łódź", 1),
    ("UK Research and Innovation", 1),
    ("Preston's College", 1),
    ("IBM Research - Thomas J. Watson Research Center", 1),
    ("Dorking Community Hospital", 1),
    ("City St George's, University of London", 1),
    ("University College London", 1),
    ("Imperial College London", 1),
    ("University of Bath", 1),
    ("Goldsmiths University of London", 1),
    ("Brunel University of London", 1),
    ("University of Glasgow", 1),
    ("University of Birmingham", 1),
    ("KU Leuven", 1)
]

# Map institutions to countries
mapping_country = {
    "University of London": "UK",
    "Robert Gordon's College": "UK",
    "University of Manchester": "UK",
    "Australian National University": "Australia",
    "Royal Military Academy Sandhurst": "UK",
    "University of Nairobi": "Kenya",
    "Rutherford Appleton Laboratory": "UK",
    "IBM (United States)": "USA",
    "University of Chester": "UK",
    "University of Nottingham": "UK",
    "University of Waterloo": "Canada",
    "Science and Technology Facilities Council": "UK",
    "Indian Institute of Technology Bombay": "India",
    "Queen Mary University of London": "UK",
    "Chinese University of Hong Kong": "China",
    "City, University of London": "UK",
    "University of Kent": "UK",
    "University of Cambridge": "UK",
    "Indian Institute of Technology Madras": "India",
    "University College Cork": "Ireland",
    "Macclesfield College": "UK",
    "University of Łódź": "Poland",
    "UK Research and Innovation": "UK",
    "Preston's College": "UK",
    "IBM Research - Thomas J. Watson Research Center": "USA",
    "Dorking Community Hospital": "UK",
    "City St George's, University of London": "UK",
    "University College London": "UK",
    "Imperial College London": "UK",
    "University of Bath": "UK",
    "Goldsmiths University of London": "UK",
    "Brunel University of London": "UK",
    "University of Glasgow": "UK",
    "University of Birmingham": "UK",
    "KU Leuven": "Belgium"
}

# Mapping countries to continents
mapping_continent = {
    "Europe": ["UK", "Poland", "Ireland", "Belgium"],
    "North America": ["USA", "Canada"],
    "Asia": ["India", "China"],
    "Africa": ["Kenya"],
    "Oceania": ["Australia"]
}

# Grouping by country
country_counts = {}
for inst, count in institutions_with_counts:
    country = mapping_country.get(inst)
    if country:
        country_counts[country] = country_counts.get(country, 0) + count

# Grouping by continent
continent_counts = {}
for continent, countries in mapping_continent.items():
    continent_counts[continent] = sum(country_counts.get(c, 0) for c in countries)

# Output results
print("Articles by country:")
for country, total in sorted(country_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{country}: {total}")

print("\nArticles by continent:")
for continent, total in sorted(continent_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{continent}: {total}")

print(f"\nTotal articles showing institution: {sum(country_counts.values())}")
print(f"Over total articles found: {102}")
# Out:
# Articles by country:
# UK: 29
# USA: 2
# India: 2
# Australia: 1
# Kenya: 1
# Canada: 1
# China: 1
# Ireland: 1
# Poland: 1
# Belgium: 1
#
# Articles by continent:
# Europe: 32
# North America: 3
# Asia: 3
# Africa: 1
# Oceania: 1
#
# Total articles showing institution: 40
# Over total articles found: 102

# %% [markdown]
# Year: 1966
#
# Query: https://openalex.org/works?page=1&filter=primary_location.source.id:s43510877,publication_year:1966

# %%
# New list of institutions with number of articles
institutions_with_counts = [
    ("University of Bristol", 5),
    ("University of London", 3),
    ("University of Surrey", 2),
    ("University College London", 2),
    ("University of East Anglia", 1),
    ("University of Huddersfield", 1),
    ("University of Leicester", 1),
    ("University of California, Los Angeles", 1),
    ("Bangor University", 1),
    ("Royal Holloway University of London", 1),
    ("University of Hull", 1),
    ("Kingston College", 1),
    ("Croydon College", 1),
    ("University of Manchester", 1),
    ("Cheshire West and Chester", 1),
    ("Malvern Community Hospital", 1),
    ("Worcestershire Health and Care NHS Trust", 1),
    ("Chelsea Primary School", 1),
    ("New College", 1),
    ("City College Brighton and Hove", 1),
    ("Grammar School", 1),
    ("Delta College of Science and Technology", 1),
    ("Imperial College London", 1),
    ("Eton College", 1),
    ("Keele University", 1),
    ("University of Worcester", 1)
]

# Map institutions to countries
mapping_country = {
    "University of Bristol": "UK",
    "University of London": "UK",
    "University of Surrey": "UK",
    "University College London": "UK",
    "University of East Anglia": "UK",
    "University of Huddersfield": "UK",
    "University of Leicester": "UK",
    "University of California, Los Angeles": "USA",
    "Bangor University": "UK",
    "Royal Holloway University of London": "UK",
    "University of Hull": "UK",
    "Kingston College": "UK",
    "Croydon College": "UK",
    "University of Manchester": "UK",
    "Cheshire West and Chester": "UK",
    "Malvern Community Hospital": "UK",
    "Worcestershire Health and Care NHS Trust": "UK",
    "Chelsea Primary School": "UK",
    "New College": "UK",
    "City College Brighton and Hove": "UK",
    "Grammar School": "UK",
    "Delta College of Science and Technology": "UK",
    "Imperial College London": "UK",
    "Eton College": "UK",
    "Keele University": "UK",
    "University of Worcester": "UK"
}

# Mapping countries to continents
mapping_continent = {
    "Europe": ["UK"],
    "North America": ["USA"]
}

# Grouping by country
country_counts = {}
for inst, count in institutions_with_counts:
    country = mapping_country.get(inst)
    if country:
        country_counts[country] = country_counts.get(country, 0) + count

# Grouping by continent
continent_counts = {}
for continent, countries in mapping_continent.items():
    continent_counts[continent] = sum(country_counts.get(c, 0) for c in countries)

# Output results
print("Articles by country:")
for country, total in sorted(country_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{country}: {total}")

print("\nArticles by continent:")
for continent, total in sorted(continent_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{continent}: {total}")

print(f"\nTotal articles showing institution: {sum(country_counts.values())}")
print(f"Over total articles found: {75}")
# Out:
# Articles by country:
# UK: 33
# USA: 1
#
# Articles by continent:
# Europe: 33
# North America: 1
#
# Total articles showing institution: 34
# Over total articles found: 75

# %% [markdown]
# # Conclusions

# %% [markdown]
# This analysis shows that in the initial years of the journals (e.g. 1966 and 1980) the affiliation of authors publishing on Physics Education journal is mostrly from UK and generally from Europe. Around 2000 authors from other continents started publishing on Physics Education, especially North America and Asia. In recent years (e.g. 2010, 2019), the journal has gaind an even more interational group of authors.
# OpenAlex does not provide the affiliation country of all published articles, but only the most frequent, preventing us to make an analysis on the total of articels published. Despite this, we consider that we have obtained a significant image of which states publish the most in the journal, confirming that Physics Education reflect mostly european contributions.
